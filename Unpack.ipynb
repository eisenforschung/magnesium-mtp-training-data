# %%
from pyiron import Project

# %%
pr = Project('.')

# %%
pr
# Out:
# {'groups': ['fit', 'fit_files', 'fit_original', 'structure_files', 'structures', 'structures_original'], 'nodes': []}

# %%
pr.unpack?
# Out:
# Signature: pr.unpack(origin_path, csv_file_name='export.csv', compress=True)
# Docstring:
# by this function, job table is imported from a given csv file,
# and also the content of project directory is copied from a given path
#
# Args:
#     origin_path (str): the relative path of a directory (or a compressed file without the tar.gz exention)
#                     from which the project directory is copied.
#     csv_file_name (str): the csv file from which the job_table is copied to the current project
#     compress (bool): if True, it looks for a compressed file
# File:      ~/software/pyiron_base/pyiron_base/project/generic.py
# Type:      method

# %% [markdown]
# # Unpack TrainingContainers with Training Data

# %%
structures_pr = pr.create_group('structures')
if len(structures_pr.list_nodes()) == 0:
    pr.unpack('structures_packed', csv_file_name='structures_packed.csv')

# %%
pr['structures'].job_table()
# Out:
#          id    status chemicalformula                job              subjob  \
# 0  17304430  finished            None              Hydro              /Hydro
# 1  17304431  finished            None            CellMin            /CellMin
# 2  17304432  finished            None             IntMin             /IntMin
# 3  17304433  finished            None             VolMin             /VolMin
# 4  17304434  finished            None             Rattle             /Rattle
# 5  17304435  finished            None  EverythingNoShear  /EverythingNoShear
# 6  17304436  finished            None              Shear              /Shear
# 7  17304437  finished            None         Everything         /Everything
# 8  17304438  finished            None            RandSPG            /RandSPG
#
#   projectpath  \
# 0    /cmmc/u/
# 1    /cmmc/u/
# 2    /cmmc/u/
# 3    /cmmc/u/
# 4    /cmmc/u/
# 5    /cmmc/u/
# 6    /cmmc/u/
# 7    /cmmc/u/
# 8    /cmmc/u/
#
# ...

# %%
fit_pr = pr.create_group('fit')
if len(fit_pr.job_table()) == 0:
    pr.unpack('fit_packed', csv_file_name='fit_packed.csv')

# %%
fit_pr.job_table()
# Out:
#           id    status chemicalformula            job          subjob  \
# 0   17322736  finished            None  MTP12_1_8_8_2  /MTP12_1_8_8_2
# 1   17322737  finished            None  MTP16_1_8_5_2  /MTP16_1_8_5_2
# 2   17322738  finished            None  MTP16_1_8_6_5  /MTP16_1_8_6_5
# 3   17322739  finished            None  MTP16_1_8_8_2  /MTP16_1_8_8_2
# 4   17322740  finished            None  MTP20_1_8_6_5  /MTP20_1_8_6_5
# 5   17322741  finished            None  MTP20_1_8_8_2  /MTP20_1_8_8_2
# 6   17322742  finished            None  MTP22_1_8_5_2  /MTP22_1_8_5_2
# 7   17322743  finished            None  MTP22_1_8_6_5  /MTP22_1_8_6_5
# 8   17322744  finished            None  MTP22_1_8_8_2  /MTP22_1_8_8_2
# 9   17322745  finished            None  MTP24_1_8_5_2  /MTP24_1_8_5_2
# 10  17322746  finished            None  MTP24_1_8_6_5  /MTP24_1_8_6_5
# 11  17322747  finished            None  MTP24_1_8_8_2  /MTP24_1_8_8_2
# ...
